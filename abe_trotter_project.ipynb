# %% [markdown]
# ## 動作確認していただきたいこと
# フォルダ "trotter_expo_coeff_gr" に以下の Error plt セクションで、得られるフィッティング結果を保存し、そのデータを使って extrapolation セクションで外挿を行う。その結果が論文の FIG.1, FIG.2, FIG.3 と同様の結果が得られることを確認していただきたいです。
#
# 流れとしては、**Error plt** で $H_2$~$H_6$($H_5$まででも可) までのフィッティングを下記の6つの積公式で行う。その結果がフォルダ "trotter_expo_coeff_gr" に保存されるので、**extrapolation** で比較する積公式を指定して、外挿する。論文の FIG.1 では、(2次, 4次, 8次(Yoshida), 8次(Morales), 10次(Morales)) を比較。FIG.2 では (4次(新構築), 8次(Morales)) を比較。
#
# フォルダ "trotter_expo_coeff_gr_original" には論文で使用しているデータが入っているので、そのデータを "trotter_expo_coeff_gr" にコピペしていただければ論文と同じ外挿が得られます。

# %% [markdown]
# ## Trotter project

# %% [markdown]
# ### ハミルトニアン基底エネルギーの計算 (t 決定用)

# %%
import trotterlib as tl
import numpy as np

Hchain = 3 # H-chain の原子数
jw_hamiltonian, E, ham_name, num_qubits = tl.jw_hamiltonian_maker(Hchain)
print(E)
print(f'Et = -π/4 を満たす t = {- np.pi / (4 * E) }')
print(f'Et = -3π/4 を満たす t = {- np.pi*3 / (4 * E) }')
print(f'Et = -5π/4 を満たす t = {- np.pi*5 / (4 * E) }')
# Out:
# H3_sto-3g_triplet_1+_distance_100_charge_1
# -1.0356826136966566
# Et = -π/4 を満たす t = 0.7583386580123526
# Et = -3π/4 を満たす t = 2.2750159740370575
# Et = -5π/4 を満たす t = 3.7916932900617626

# %% [markdown]
# ### **Error plt**
#
# #### t の値：
# Et = ± $\pi$ / 2 となるような t は避ける。経験的に、小数点1桁離せばほぼ直線となる。目安として Et  $\sim n * \pi$ / 4 となるような t を選んだ。
# 高次の積公式では、Et  $\sim \pi$ / 4 だと、誤差がマシンイプシロンに引っかかるため、 Et  $\sim 3 * \pi$ / 4 などに調整。Morales の積公式は $\sim 3 * \pi$ / 4 推奨
# ステップ幅は t の 0.002 程度
#
#
# #### t の例 （Morales 以外, Morales）
# $H_2$ : 0.73, 2.21
# $H_3$ : 0.75, 2.27
# $H_4$ : 0.37, 1.12
# $H_5$ : 0.36, 1.08
# $H_6$ : 0.25, 1.25
# $H_7$ : 0.23, 1.19
# $H_{8}$ : 0.18, 0.94
# $H_{9}$ : 0.18, 0.90
# $H_{10}$ : 0.15, 0.75
# $H_{11}$ : 0.14, 0.72
# $H_{12}$ : 0.12, 0.62
# $H_{13}$ : 0.12, 0.60
# $H_{14}$ : 0.10, 0.53
# $H_{15}$ : 0.10, 0.51
#
#
# #### 積公式の種類表記(pf_label)：
# 2nd : 2次,
# 4th : 4次,
# 8th(Yoshida) : Yoshidaの8次,
# 8th(Morales) : Moralesらの8次(m=8),
# 10th(Morales) : Moralesらの10次(m=16),
# 4th(new_2) : 新構築4次(係数2個),
#
#
#
# #### フィッティング結果(データ保存)：
# ディレクトリ : "trotter_expo_coeff_gr" に保存される。保存されるのは、誤差 $\alpha t^p$ のスケーリングを、$\alpha, p$ の両方で行ったもの、と $p$ を次数で固定し、$\alpha$ だけでスケーリングしたもの。
# 保存名は、"｛ハミルトニアンの情報｝＿｛pf_label｝＿｛$p$ を固定しているのであれば ave｝"
# ハミルトニアン:H3, 使用積公式:4次, $p$ の固定ありの場合の保存名例:
# H3_sto-3g_triplet_1+_distance_100_charge_1_grouping_Operator_4th_ave
# **変数'avestrage=True'とすることでフィッティング結果を保存する。外挿を行う。**

# %% [markdown]
# ローカル CPU だと $H_7$ あたりが限界

# %%
import trotterlib as tl

time_dir = {2:{0:0.73,1:2.21},3:{0:0.75,1:2.27},4:{0:0.37,1:1.12},5:{0:0.36,1:1.08},6:{0:0.25,1:1.25},7:{0:0.23,1:1.19}, 8:{0.18, 0.94}, 9:{0.18, 0.90}, 10:{0.15, 0.75}, 11:{0.14, 0.72}, 12:{0.12, 0.62}, 13:{0.12, 0.60}, 14:{0.10, 0.53}, 15:{0.10, 0.51}} # 初時間セット
t_step = 0.002 # ステップ幅

Hchain = 2 # H-chain
pf_label = '2nd' # 使用積公式
save = False # フィッティング α, p 保存可否

# フィッテング結果を保存する際はここを True にする
ave_coeff_save = False # フィッティング α (p 固定) 保存可否

if pf_label in ('8th(Morales)', '10th(Morales)'):
    t_start = time_dir[Hchain][1]
    print("good")
else:
    t_start = time_dir[Hchain][0]
t_end = t_start + 0.01
tl.trotter_error_plt_qc_gr(t_start, t_end, t_step, Hchain, pf_label, save, ave_coeff_save)
# Out:
# H2_sto-3g_singlet_distance_100_charge_0
# energy_-0.7735421405578118
# error exponent :2.076809941067563
# error coefficient :0.0034362184906225634
# r^2 (log-log): 0.9999999681339498
# average_coeff:0.003355907244646522

# %% [markdown]
# #### 同一 t に対して一括で複数のフィッティング用

# %%
import trotterlib as tl

time_dir = {2:{0:0.73,1:2.21},3:{0:0.75,1:2.27},4:{0:0.37,1:1.12},5:{0:0.36,1:1.08},6:{0:0.25,1:1.25},7:{0:0.23,1:1.19}} # 初時間セット
dividing = 0.002 # ステップ幅

Hchain = 3 # H-chain
storage = None # フィッティング α, p 保存可否
avestrage = None # フィッティング α (p 固定) 保存可否

num_w_list = ["2nd", "4th", "8th(Yoshida)", "4th(new_2)", "8th(Morales)","10th(Morales)"]
for num_w in num_w_list:
    if num_w == '8th(Morales)' or num_w == '10th(Morales)':
        s_time = time_dir[Hchain][1]
    else:
        s_time = time_dir[Hchain][0]
    e_time = s_time + 0.01
    tl.trotter_error_plt_qc_gr(s_time, e_time, dividing, Hchain, num_w, storage, avestrage)
# Out:
# H3_sto-3g_triplet_1+_distance_100_charge_1
# energy_-1.2347230243846221
# error exponent :2.1732545527742366
# error coefficient :0.005520939425674299
# r^2 (log-log): 0.999999681282351
# average_coeff:0.005258549493699829
# H3_sto-3g_triplet_1+_distance_100_charge_1
# energy_-1.2347230243846237
# error exponent :3.8364604731998013
# error coefficient :0.001876194253766155
# r^2 (log-log): 0.9999999674082369
# average_coeff:0.0019644411645436573
# H3_sto-3g_triplet_1+_distance_100_charge_1
# energy_-1.2347230243846266
# error exponent :6.380049159509742
# error coefficient :0.0026025690270927064
# r^2 (log-log): 0.9999562062200932
# average_coeff:0.0041032633865273616
# H3_sto-3g_triplet_1+_distance_100_charge_1
# energy_-1.2347230243846274
# error exponent :3.9010557009474827
# error coefficient :2.787019879107252e-05
# r^2 (log-log): 0.9999999863254487
# average_coeff:2.865609178233667e-05
# H3_sto-3g_triplet_1+_distance_100_charge_1
# energy_-1.234723024384628
# ...

# %% [markdown]
# ### 摂動論による基底エネルギーの推定誤差(直接対角化との比較) (FIG.6)

# %%
import trotterlib as tl
s_time = 0.008 # 初時刻
e_time = 0.018 # 終時刻
dividing = 0.001 # ステップ幅
Hchain = 2 # H-chain
num_w = '2nd' # 使用積公式

tl.trotter_error_plt_qc(s_time, e_time, dividing, Hchain, num_w)
# Out:
# converged SCF energy = -1.06610864931794
# H2_sto-3g_singlet_distance_100_charge_0
# error exponent :2.000017201067613
# error coefficient :0.003241491025559686
# r^2 (log-log): 0.9999999999967266
# average_coeff:0.0032412451592006004
# H2_sto-3g_singlet_distance_100_charge_0
# m1m1m1m1
#
#
#
# idx 1 ham (-0.3276081896748093+0j) []
# idx 2 ham (0.13716572937099508+0j) [Z0]
# idx 1 ham (-0.3276081896748093+0j) []idx 1 ham (-0.3276081896748093+0j) []
#
# idx 3 ham (0.13716572937099503+0j) [Z1]
# idx 2 ham (0.13716572937099508+0j) [Z0]idx 2 ham (0.13716572937099508+0j) [Z0]
#
# idx 4 ham (-0.13036292057109103+0j) [Z2]
# idx 1 ham (-0.3276081896748093+0j) []idx 3 ham (0.13716572937099503+0j) [Z1]
# idx 3 ham (0.13716572937099503+0j) [Z1]
#
# idx 5 ham (-0.13036292057109103+0j) [Z3]
# idx 4 ham (-0.13036292057109103+0j) [Z2]idx 4 ham (-0.13036292057109103+0j) [Z2]
#
# idx 6 ham (0.15660062488237947+0j) [Z0 Z1]
# ...

# %% [markdown]
# ### extrapolation  (FIG.1, FIG.2)
# H-chain の総計算量をプロットして、そのプロットを使って、外挿を行う。
# ディレクトリ "trotter_expo_coeff_gr" のスケーリング結果の $\alpha$ から総計算量を決定し、それに対して外挿する。
# そのため、変数 Hchain の原子数において上の Error plt でフィッティングを行っている必要がある。
# $H_2$ ~  $H_7$ ( $H_6, H_5$まででも可 ) までのフィッティングでも論文と同様の結果が得られる。
# フォルダ "trotter_expo_coeff_gr_original" には論文で使用している $H_{15}$ までのフィッティング結果を格納済み
#
# **ここでの外挿は "trotter_expo_coeff_gr" に保存した(このノートブックで保存したもの)をもとに外挿するので、論文と同じ結果を表示するには、use_original=True で "trotter_expo_coeff_gr_original" のデータを使用し、Hchain=15 に設定する。**

# %%
import trotterlib as tl
Hchain = 15 # プロットを行う H-chain の原子数。上の Error plt でスケーリング済みの必要あり。
n_w_list = ['2nd', '4th', '8th(Yoshida)', '8th(Morales)', '10th(Morales)'] # 比較するPF FIG.1
tl.exp_extrapolation(Hchain, n_w_list, show_bands=True, use_original=True) # show_bands: 外挿の最小Fとなる PF の色帯をプロット下部に表示 

# rz_layer=True で RZ のレイヤー数(depth) でプロット , False なら T-depth
n_w_list = ['2nd', '4th', '8th(Yoshida)', '8th(Morales)', '10th(Morales)'] # 比較するPF FIG.2
tl.t_depth_extrapolation(Hchain, n_w_list, rz_layer=True,show_bands=True, use_original=True) # show_bands: 外挿の最小Fとなる PF の色帯をプロット下部に表示
# Out:
# T_rot:173.1628705100568 PF:2nd
# T_rot:160.2427385747507 PF:4th
# T_rot:164.7139969967671 PF:8th(Yoshida)
# T_rot:151.44174652973848 PF:8th(Morales)

# %% [markdown]
# #### 2つの積公式の総ゲート数の差分を表示(FIG.3)
# **論文と同じ結果を表示するには、use_original=True で "trotter_expo_coeff_gr_original" のデータを使用し、Hchain=15 に設定する。**

# %%
import trotterlib as tl
Hchain = 15 # プロットを行う H-chain の原子数。上の Error plt でスケーリング済みの必要あり。
n_w_list = ['8th(Morales)', '4th(new_2)'] # 比較するPF 2つ
tl.exp_extrapolation_diff(Hchain, n_w_list, use_original=False) # show_bands: 外挿の最小Fとなる PF の色帯をプロット下部に表示

# %% [markdown]
# #### 許容誤差(縦軸)ごとに最小ゲート数となる積公式(単一分子)(FIG.7)

# %%
import trotterlib as tl

Hchain=2
n_w_list = ['2nd', '4th', '8th(Morales)', '8th(Yoshida)', '10th(Morales)'] # 比較するPF
tl.num_gate_plot_grouping(Hchain, n_w_list, use_original=False)
# Out:
# H2_sto-3g_singlet_distance_100_charge_0

# %% [markdown]
# #### 許容誤差(縦軸)ごとに最小ゲート数となる積公式(FIG.8, FIG.9)

# %%
import trotterlib as tl

H_chain = 15

n_w_list = ['2nd', '4th', '8th(Morales)', '8th(Yoshida)', '10th(Morales)'] # 比較するPF FIG.8
tl.efficient_accuracy_range_plt_grouper(H_chain, n_w_list, use_original=False)

n_w_list = ['2nd', '4th', '8th(Morales)', '8th(Yoshida)', '4th(new_3)', '4th(new_2)'] # 比較するPF FIG.9
tl.efficient_accuracy_range_plt_grouper(H_chain, n_w_list, use_original=False)
# Out:
# H2_sto-3g_singlet_distance_100_charge_0
# H3_sto-3g_triplet_1+_distance_100_charge_1
# H4_sto-3g_singlet_distance_100_charge_0
# H5_sto-3g_triplet_1+_distance_100_charge_1
# H6_sto-3g_singlet_distance_100_charge_0
# H7_sto-3g_triplet_1+_distance_100_charge_1
# H8_sto-3g_singlet_distance_100_charge_0
# H9_sto-3g_triplet_1+_distance_100_charge_1
# H10_sto-3g_singlet_distance_100_charge_0
# H11_sto-3g_triplet_1+_distance_100_charge_1
# H12_sto-3g_singlet_distance_100_charge_0
# H13_sto-3g_triplet_1+_distance_100_charge_1
# H14_sto-3g_singlet_distance_100_charge_0
# H15_sto-3g_triplet_1+_distance_100_charge_1
# H2_sto-3g_singlet_distance_100_charge_0
# H3_sto-3g_triplet_1+_distance_100_charge_1
# H4_sto-3g_singlet_distance_100_charge_0
# H5_sto-3g_triplet_1+_distance_100_charge_1
# H6_sto-3g_singlet_distance_100_charge_0
# H7_sto-3g_triplet_1+_distance_100_charge_1
# H8_sto-3g_singlet_distance_100_charge_0
# H9_sto-3g_triplet_1+_distance_100_charge_1
# ...

# %% [markdown]
# ### T-depth / RZ-layer depth 外挿

# %%
import trotterlib as tl
n_w_list = ['2nd', '4th', '8th(Morales)', '8th(Yoshida)', '4th(new_3)', '4th(new_2)'] # 比較するPF
H_chain = 15
tl.t_depth_extrapolation(H_chain, n_w_list, rz_layer=True)
# Out:
# T_rot:173.1628705100568 PF:2nd
# T_rot:160.2427385747507 PF:4th
# T_rot:151.44174652973848 PF:8th(Morales)
# T_rot:164.7139969967671 PF:8th(Yoshida)
# T_rot:153.39283937749968 PF:4th(new_3)
# T_rot:153.8602771006849 PF:4th(new_2)

# %% [markdown]
# ### T-depth / RZ-layer depth 外挿差分表示 (FIG.4)

# %%
import trotterlib as tl
n_w_list = ['4th(new_2)', '8th(Morales)'] # 比較するPF
H_chain = 15
tl.t_depth_extrapolation_diff(H_chain, rz_layer=True, n_w_list=n_w_list)
# Out:
# T_rot:153.8602771006849 PF:4th(new_2)
# T_rot:151.44174652973848 PF:8th(Morales)
# 4th (new, m=2)_Tdepth_at_100qubits = 128795687819.64124
# 8th (Morales et al.)_Tdepth_at_100qubits = 160036456853.12723

# %% [markdown]
# ### Rz-layer 算出周り
# 各 grouping 内の A, n 型の FermionOperator を Z string のサポートに展開し、サポート同士が同じ qubit を共有する場合は同じレイヤーに置けないとして、greedy coloring によりグループごとの RZ-layer 数を見積もる。
# そのグループごとのレイヤー数を PF の順序に沿って足し上げることで、PF 1 step あたりの RZ-layer 数を得る。

# %%
from trotterlib.rz_layers import (
    RZ_LAYER_DIR,
    generate_rz_layer_dir,
    assert_generated_rz_layer_dir_matches_static,
)

# 小さい H-chain で RZ_layer_dir 自体を生成
h_chains = [2, 3, 4]
generated_rz_layer_dir = generate_rz_layer_dir(h_chains)

# 既存 config 元の固定値と一致するか確認
assert_generated_rz_layer_dir_matches_static(generated_rz_layer_dir)

generated_rz_layer_dir
# Out:
# {2: (4, 1),
#  3: (8, 4, 4, 1, 1, 1, 1),
#  4: (9, 5, 5, 4, 4, 4, 4, 4, 2, 3, 2, 2, 3)}

# %%
import pandas as pd

from trotterlib.rz_layers import build_pf_rz_layer_table_from_group_layers

pf_rz_layer = build_pf_rz_layer_table_from_group_layers(generated_rz_layer_dir)

pd.DataFrame(pf_rz_layer).T
# Out:
#     2nd  4th  8th(Morales)  10th(Morales)  8th(Yoshida)  4th(new_3)  \
# H2    9   19            89            169            79          39
# H3   39  101           535           1031           473         225
# H4   99  279          1539           2979          1359         639
#
#     4th(new_2)
# H2          29
# H3         163
# H4         459

# %% [markdown]
# ### 積公式構築
# $t^k$ までのテイラー展開で数値最適化を行い積公式のパラメータ[$w_1,...w_m$]を決定。残差が threshold より小さくなるパラメータを n_targets 個集めてその中で最も残差が小さいものを返す

# %%
import trotterlib.optimal_trotter as ot

best_w, best_total = ot.parallel_find(m=2, k=4, n_targets=10, threshold=1e-17)
print(f"最良の optimalw: {best_w}")
print(f"対応する total: {best_total}") # 残差
# Out:
# 最良の optimalw: [0.58074718 0.30141155]
# 対応する total: 7.653789711389858e-18

# %% [markdown]
# #### 残差比較

# %%
import numpy as np
import trotterlib.optimal_trotter as ot

cand_search_best = {
    "name": "search_best",
    "w_free": [0.42008729, 0.40899193]
}

cand_known = {
    "name": "known_formula",
    "w_free": [0.29534665, 0.59302617]
}


results = ot.compare_residuals(
    formulas=[cand_search_best, cand_known],
    k=5,
    sort_by="l2"   # L1ノルム(総誤差)が小さい順に並べる
)

for r in results:
    print("----", r["name"], "----")
    print("  L1 sum  :", r["l1"])
    print("  L2 norm :", r["l2"])
    print("  Linf max:", r["linf"])
    print("  w_free  :", r["w_free"])
    # 必要なら r["rest_vec"] (np.longdoubleでの項別のズレ) も見れる
# Out:
# ---- search_best ----
#   L1 sum  : 0.039866335337528945
#   L2 norm : 0.008970465504813528
#   Linf max: 0.004442794159854848
#   w_free  : [0.42008729 0.40899193]
# ---- known_formula ----
#   L1 sum  : 0.05445272786621607
#   L2 norm : 0.012580145070478667
#   Linf max: 0.0067086293029674
#   w_free  : [0.29534665 0.59302617]

# %% [markdown]
# ### $\beta$ スケーリング

# %% [markdown]
# #### スケーリング例 (FIG.5)

# %%
import trotterlib.qpe_beta as qb
import numpy as np

T_list_QPE = np.array([128,256,512,1024,2048,4096,8192,16384,32768]) # M
N_rep = 10       # 繰り返し回数
N_QPE = 100 # サンプリング数
initial_phi = [-1.5]
qb.beta_plt(T_list_QPE, N_rep, N_QPE, initial_phi)
# Out:
# α (fixed) = 1.0
# β (fitted) = 1.433

# %% [markdown]
# #### ランダムな初期位相に対して得られる β の平均値

# %%
import trotterlib.qpe_beta as qb
import numpy as np
T_list_QPE = np.array([128,256,512,1024,2048,4096,8192,16384,32768]) # M
N_rep = 10       # 繰り返し回数
N_QPE = 100 # サンプリング数
qb.beta_scaling(T_list_QPE, N_rep, N_QPE)
# Out:
# Mean beta_fix over 100 trials: 1.20895827228886
# Std  beta_fix over 100 trials: 0.48379796103054173
